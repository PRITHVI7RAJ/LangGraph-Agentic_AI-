# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    # fetch title
    title = state['title']
    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

#node
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

#edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)


workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Okay, here\'s a detailed outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and informative.\n\n---\n\n## Blog Title Ideas:\n*   India\'s AI Ascent: Decoding the Revolution Shaping its Future\n*   The AI Awakening: How India is Embracing the Intelligence Revolution\n*   Beyond the Hype: The Real Story of AI\'s Rise in India\n*   From Bangalore to Bharat: Charting India\'s AI Journey\n*   India\'s AI Moment: Opportunities, Challenges, and the Road Ahead\n\n---\n\n## **Blog Outline: India\'s AI Ascent: Decoding the Revolution Shaping its Future**\n\n**Target Audience:** Tech enthusiasts, business leaders, policymakers, students, general public interested in India\'s technological advancements.\n\n**Tone:** Optimistic yet realistic, informative, analytical, forward-looking.\n\n**Keywords:** AI India, Artificial Intelligence India, Indian AI startups, AI policy India, Digital India, AI applications India, Indian tech sector, AI challenges India, AI opportunities India.\n\n---\n\n### **I. Introduction (Approx. 150-200 words)**\n\n*   **A. Hook:** Start with a compelling statement about the global AI revolution and its transformative power.\n    *   *Example:* "From self-driving cars to personalized healthcare, Artificial Intelligence is reshaping our world at an unprecedented pace. But nowhere is its ascent more dynamic and uniquely tailored than in India."\n*   **B. Contextualize India\'s Position:** Briefly introduce India as a rising global player in the AI landscape, moving beyond just being an IT services hub.\n    *   Mention its vast digital population, tech talent pool, and government push.\n*   **C. Thesis Statement:** Clearly state what the blog post will cover – exploring the drivers behind India\'s AI boom, its diverse applications, the ecosystem, opportunities, and the critical challenges it must navigate.\n*   **D. Brief Roadmap:** Hint at the major sections to follow.\n\n### **II. The Genesis of India\'s AI Boom: What\'s Driving It? (Approx. 300 words)**\n\n*   **A. Human Capital Advantage:**\n    *   India\'s massive pool of STEM graduates.\n    *   Growing interest in data science, machine learning, and AI.\n    *   Return of skilled diaspora.\n*   **B. Digital Infrastructure & Adoption:**\n    *   **Jio Revolution & Affordable Data:** Democratization of internet access.\n    *   **UPI & Digital Payments:** Massive datasets for financial AI.\n    *   **Aadhaar & India Stack:** Foundational digital identity and services creating a data-rich environment.\n*   **C. Government Initiatives & Policy Push:**\n    *   **NITI Aayog\'s "National Strategy for Artificial Intelligence" (AI #ForALL):** Focus on inclusive growth.\n    *   **"Digital India" & "Make in India" initiatives:** Creating an enabling environment for tech.\n    *   **Investment in AI research & development centers.**\n*   **D. Thriving Startup Ecosystem:**\n    *   Rise of numerous AI-focused startups in major cities (Bangalore, Hyderabad, Delhi-NCR, Pune).\n    *   Access to venture capital and angel funding.\n*   **E. Large Domestic Market & Unique Problems:**\n    *   India\'s scale presents unique challenges that AI can solve (e.g., agriculture, healthcare access, multilingual communication).\n\n### **III. AI in Action: Transforming Key Indian Sectors (Approx. 400 words)**\n\n*   **A. Healthcare:**\n    *   **Diagnostics:** AI-powered tools for early detection of diseases (e.g., retinal scans for diabetic retinopathy, cancer screening).\n    *   **Drug Discovery & Research:** Accelerating R&D.\n    *   **Telemedicine & Remote Monitoring:** Bridging urban-rural healthcare gaps.\n    *   **Personalized Treatment Plans.**\n*   **B. Agriculture (AgriTech):**\n    *   **Crop Yield Prediction:** Using satellite imagery and weather data.\n    *   **Pest and Disease Detection:** AI-powered drones and sensors.\n    *   **Precision Farming:** Optimized irrigation and fertili ...

# %%
print(final_state['outline'])
# Out:
# Okay, here's a detailed outline for a blog post on "The Rise of AI in India," designed to be comprehensive, engaging, and informative.
#
# ---
#
# ## Blog Title Ideas:
# *   India's AI Ascent: Decoding the Revolution Shaping its Future
# *   The AI Awakening: How India is Embracing the Intelligence Revolution
# *   Beyond the Hype: The Real Story of AI's Rise in India
# *   From Bangalore to Bharat: Charting India's AI Journey
# *   India's AI Moment: Opportunities, Challenges, and the Road Ahead
#
# ---
#
# ## **Blog Outline: India's AI Ascent: Decoding the Revolution Shaping its Future**
#
# **Target Audience:** Tech enthusiasts, business leaders, policymakers, students, general public interested in India's technological advancements.
#
# **Tone:** Optimistic yet realistic, informative, analytical, forward-looking.
#
# **Keywords:** AI India, Artificial Intelligence India, Indian AI startups, AI policy India, Digital India, AI applications India, Indian tech sector, AI challenges India, AI opportunities India.
#
# ---
#
# ### **I. Introduction (Approx. 150-200 words)**
#
# *   **A. Hook:** Start with a compelling statement about the global AI revolution and its transformative power.
#     *   *Example:* "From self-driving cars to personalized healthcare, Artificial Intelligence is reshaping our world at an unprecedented pace. But nowhere is its ascent more dynamic and uniquely tailored than in India."
# *   **B. Contextualize India's Position:** Briefly introduce India as a rising global player in the AI landscape, moving beyond just being an IT services hub.
#     *   Mention its vast digital population, tech talent pool, and government push.
# *   **C. Thesis Statement:** Clearly state what the blog post will cover – exploring the drivers behind India's AI boom, its diverse applications, the ecosystem, opportunities, and the critical challenges it must navigate.
# *   **D. Brief Roadmap:** Hint at the major sections to follow.
#
# ### **II. The Genesis of India's AI Boom: What's Driving It? (Approx. 300 words)**
#
# *   **A. Human Capital Advantage:**
#     *   India's massive pool of STEM graduates.
#     *   Growing interest in data science, machine learning, and AI.
#     *   Return of skilled diaspora.
# *   **B. Digital Infrastructure & Adoption:**
#     *   **Jio Revolution & Affordable Data:** Democratization of internet access.
#     *   **UPI & Digital Payments:** Massive datasets for financial AI.
#     *   **Aadhaar & India Stack:** Foundational digital identity and services creating a data-rich environment.
# *   **C. Government Initiatives & Policy Push:**
#     *   **NITI Aayog's "National Strategy for Artificial Intelligence" (AI #ForALL):** Focus on inclusive growth.
#     *   **"Digital India" & "Make in India" initiatives:** Creating an enabling environment for tech.
#     *   **Investment in AI research & development centers.**
# *   **D. Thriving Startup Ecosystem:**
#     *   Rise of numerous AI-focused startups in major cities (Bangalore, Hyderabad, Delhi-NCR, Pune).
#     *   Access to venture capital and angel funding.
# *   **E. Large Domestic Market & Unique Problems:**
#     *   India's scale presents unique challenges that AI can solve (e.g., agriculture, healthcare access, multilingual communication).
#
# ### **III. AI in Action: Transforming Key Indian Sectors (Approx. 400 words)**
#
# *   **A. Healthcare:**
#     *   **Diagnostics:** AI-powered tools for early detection of diseases (e.g., retinal scans for diabetic retinopathy, cancer screening).
#     *   **Drug Discovery & Research:** Accelerating R&D.
#     *   **Telemedicine & Remote Monitoring:** Bridging urban-rural healthcare gaps.
#     *   **Personalized Treatment Plans.**
# *   **B. Agriculture (AgriTech):**
#     *   **Crop Yield Prediction:** Using satellite imagery and weather data.
#     *   **Pest and Disease Detection:** AI-powered drones and sensors.
#     *   **Precision Farming:** Optimized irrigation and fertilization.
#     *   **Market Price Prediction:** Helping farmers make informed decisions.
# *   **C. Finance (FinTech):**
#     *   **Fraud Detection & Prevention:** Real-time anomaly detection.
#     *   **Personalized Banking & Investment Advice:** Robo-advisors.
#     *   **Credit Scoring for Underserved Populations:** Alternative data analysis.
#     *   **Customer Service:** AI chatbots and virtual assistants.
# *   **D. Education (EdTech):**
#     *   **Personalized Learning Paths:** Adaptive educational content.
#     *   **Automated Grading & Feedback.**
#     *   **Language Learning Tools** (critical for India's linguistic diversity).
# *   **E. E-commerce & Retail:**
#     *   **Personalized Recommendations.**
#     *   **Supply Chain Optimization.**
#     *   **Customer Support Chatbots.**
# *   **F. Automotive & Manufacturing:**
#     *   **Autonomous Driving Research.**
#     *   **Predictive Maintenance in Factories.**
#     *   **Quality Control & Automation.**
# *   **G. Public Services & Governance:**
#     *   **Smart City Solutions.**
#     *   **Traffic Management.**
#     *   **Disaster Management.**
#     *   **Citizen Engagement Platforms.**
#
# ### **IV. The Ecosystem: Players and Collaborations (Approx. 250 words)**
#
# *   **A. Indian Tech Giants:**
#     *   TCS, Infosys, Wipro, HCLTech investing heavily in AI R&D and solutions.
#     *   Setting up dedicated AI labs and acquiring AI startups.
# *   **B. Startups & Unicorns:**
#     *   Highlight a few notable Indian AI startups (e.g., conversational AI, computer vision, natural language processing).
#     *   Role of accelerators and incubators.
# *   **C. Academia & Research Institutions:**
#     *   IITs, IISc, top universities contributing to fundamental and applied AI research.
#     *   Industry-academia partnerships.
# *   **D. MNCs & Global Partnerships:**
#     *   Google, Microsoft, IBM, Amazon establishing AI research centers and talent hubs in India.
#     *   Collaborations with Indian companies and government.
#
# ### **V. Opportunities & The Road Ahead (Approx. 200 words)**
#
# *   **A. Economic Growth & GDP Boost:** Potential to add trillions to India's economy.
# *   **B. Job Creation:** Emergence of new roles (AI engineers, data scientists, ethicists).
# *   **C. Social Impact:** Addressing critical societal challenges (poverty, health, education).
# *   **D. Global AI Leadership:** India's potential to become a net exporter of AI solutions.
# *   **E. "AI for Bharat":** Developing localized, frugal AI solutions for unique Indian contexts.
#
# ### **VI. Navigating the Challenges & Ethical Considerations (Approx. 300 words)**
#
# *   **A. Skill Gap & Reskilling:**
#     *   Need for continuous upskilling and reskilling of the workforce.
#     *   Bridging the gap between academic knowledge and industry demands.
# *   **B. Data Privacy & Security:**
#     *   Ensuring robust data protection frameworks (e.g., upcoming Digital Personal Data Protection Bill).
#     *   Preventing misuse of vast datasets.
# *   **C. Ethical AI & Bias:**
#     *   Addressing algorithmic bias in decision-making (e.g., credit scoring, hiring).
#     *   Ensuring fairness, transparency, and accountability in AI systems.
#     *   **"Explainable AI" (XAI) for trust.**
# *   **D. Infrastructure & Compute Power:**
#     *   Need for robust cloud infrastructure and high-performance computing.
#     *   Ensuring equitable access across regions.
# *   **E. Job Displacement Concerns:**
#     *   Addressing fears of automation leading to job losses.
#     *   Focus on human-AI collaboration and creating new roles.
# *   **F. Regulatory Framework:**
#     *   Developing agile and effective regulations that foster innovation while mitigating risks.
#     *   Balancing innovation with safety and ethics.
#
# ### **VII. Conclusion (Approx. 150-200 words)**
#
# *   **A. Recap Key Points:** Briefly summarize India's unique position, the drivers of its AI growth, its diverse applications, and the dual nature of opportunities and challenges.
# *   **B. Reiterate Thesis:** Emphasize that India is not just adopting AI, but actively shaping its future, especially with a focus on inclusive and impactful solutions.
# *   **C. Future Outlook:** Express optimism about India's trajectory in the global AI landscape, provided it proactively addresses its challenges.
# *   **D. Call to Action/Thought-Provoking Question:**
#     *   *Example:* "As India continues its remarkable AI ascent, the synergy of its talent, digital infrastructure, and policy vision holds the key to unlocking a future where AI truly empowers every Indian. How do you envision AI transforming your daily life in India over the next decade?"
#     *   Encourage comments and discussion.
#
# ---
#
# ### **Optional Additions for Blog Engagement:**
#
# *   **Infographics/Data Visualizations:** Key stats on AI adoption, investment, or sector-wise impact.
# *   **Quotes:** From industry leaders, policymakers, or AI researchers in India.
# *   **Case Studies:** Short, compelling examples of AI solutions solving real Indian problems.
# *   **Related Articles/Resources:** Links to NITI Aayog reports, academic papers, or news articles.
#
# ---

# %%
print(final_state['content'])
# Out:
# ## India's AI Ascent: Decoding the Revolution Shaping its Future
#
# From self-driving cars to personalized healthcare, Artificial Intelligence is reshaping our world at an unprecedented pace. This global AI revolution is not merely a distant technological marvel but a palpable force transforming economies and societies right now. While tech giants in the West and East have long dominated the narrative, nowhere is AI's ascent more dynamic, uniquely tailored, and brimming with potential than in India.
#
# No longer content with being just the world’s back office for IT services, India is rapidly emerging as a formidable global player in the AI landscape. Driven by its vast digital population, a burgeoning tech talent pool, and an ambitious government push, the nation is harnessing AI to solve its unique challenges and unlock unprecedented growth. This blog post will delve into the powerful drivers behind India's AI boom, explore its diverse and impactful applications across critical sectors, illuminate the vibrant ecosystem fostering its growth, highlight the immense opportunities it presents, and critically examine the significant challenges India must navigate to truly realize its AI destiny.
#
# ### The Genesis of India's AI Boom: What's Driving It?
#
# India's journey to becoming an AI powerhouse isn't accidental; it's the result of several converging forces creating a fertile ground for innovation. At its core lies an unparalleled **human capital advantage**. With a massive pool of STEM graduates, a rapidly growing interest in data science, machine learning, and AI, and the strategic return of skilled diaspora, India possesses the intellectual firepower crucial for AI development.
#
# Complementing this talent is a robust **digital infrastructure and adoption**. The "Jio Revolution" democratized internet access, making affordable data available to hundreds of millions, thus creating a massive digital footprint. Platforms like **UPI (Unified Payments Interface)** have revolutionized digital payments, generating immense datasets crucial for financial AI. Furthermore, the **Aadhaar system and India Stack** provide foundational digital identities and services, creating an unparalleled data-rich environment for AI applications.
#
# The **government's proactive initiatives and policy push** have been instrumental. NITI Aayog's **"National Strategy for Artificial Intelligence" (AI #ForALL)** focuses on inclusive growth, while "Digital India" and "Make in India" initiatives foster an enabling environment for tech. Significant investments in AI research and development centers further underscore this commitment. This supportive framework, coupled with a **thriving startup ecosystem**, has seen numerous AI-focused startups emerge in major cities, attracting venture capital and angel funding. Finally, India's **large domestic market and unique problems** present a compelling opportunity. The sheer scale of its challenges in sectors like agriculture, healthcare access, and multilingual communication makes AI not just a luxury, but a necessity for sustainable development.
#
# ### AI in Action: Transforming Key Indian Sectors
#
# The impact of AI is reverberating across nearly every sector of the Indian economy, offering innovative solutions to long-standing problems.
#
# In **Healthcare**, AI is a game-changer for diagnostics, enabling AI-powered tools for early detection of diseases like diabetic retinopathy and various cancers through retinal scans and medical imaging analysis. It's accelerating **drug discovery and research**, and bridging urban-rural healthcare gaps through **telemedicine and remote monitoring**. AI also facilitates **personalized treatment plans**, tailoring medical approaches to individual patient data.
#
# **Agriculture (AgriTech)**, a cornerstone of the Indian economy, is being revitalized by AI. Farmers can benefit from **crop yield prediction** using satellite imagery and weather data, **pest and disease detection** via AI-powered drones and sensors, and **precision farming** for optimized irrigation and fertilization. AI also helps with **market price prediction**, empowering farmers with informed decisions.
#
# The **Finance (FinTech)** sector leverages AI for real-time **fraud detection and prevention**, personalized banking through **robo-advisors** for investment advice, and crucial **credit scoring for underserved populations** using alternative data analysis. AI chatbots and virtual assistants are also enhancing **customer service**.
#
# In **Education (EdTech)**, AI is enabling **personalized learning paths** with adaptive content, **automated grading and feedback**, and innovative **language learning tools**, which are critical in India's linguistically diverse environment.
#
# **E-commerce & Retail** thrive on AI for **personalized recommendations**, **supply chain optimization**, and efficient **customer support chatbots**. The **Automotive & Manufacturing** sectors are seeing advancements in **autonomous driving research**, **predictive maintenance** in factories, and enhanced **quality control and automation**.
#
# Finally, in **Public Services & Governance**, AI is powering **smart city solutions**, intelligent **traffic management**, proactive **disaster management**, and more effective **citizen engagement platforms**, promising improved governance and quality of life.
#
# ### The Ecosystem: Players and Collaborations
#
# India's AI ecosystem is a dynamic interplay of various stakeholders. **Indian tech giants** like TCS, Infosys, Wipro, and HCLTech are heavily investing in AI R&D, establishing dedicated AI labs, and strategically acquiring AI startups to bolster their capabilities.
#
# The vibrant **startup and unicorn landscape** is a significant driver, with numerous Indian AI startups making waves in conversational AI, computer vision, and natural language processing. Accelerators and incubators play a crucial role in nurturing these nascent ventures.
#
# **Academia and research institutions**, particularly the IITs, IISc, and other top universities, are contributing significantly to both fundamental and applied AI research, often through robust **industry-academia partnerships**.
#
# Furthermore, **MNCs and global partnerships** are injecting global expertise and investment. Companies like Google, Microsoft, IBM, and Amazon have established AI research centers and talent hubs in India, fostering collaborations with local companies and the government, further integrating India into the global AI narrative.
#
# ### Opportunities & The Road Ahead
#
# The potential of AI in India is immense, promising transformative impacts on its economy and society. It holds the potential for significant **economic growth and a substantial GDP boost**, with estimates suggesting it could add trillions to India's economy. This growth will naturally lead to **job creation**, giving rise to new roles such as AI engineers, data scientists, and AI ethicists.
#
# Beyond economics, AI offers profound **social impact**, addressing critical societal challenges like poverty, health disparities, and educational access. India also has the potential to achieve **global AI leadership**, moving beyond consumption to become a net exporter of innovative AI solutions. A key focus is **"AI for Bharat,"** emphasizing the development of localized, frugal AI solutions specifically tailored for unique Indian contexts and diverse populations.
#
# ### Navigating the Challenges & Ethical Considerations
#
# Despite the exciting opportunities, India's AI journey is not without its hurdles and ethical dilemmas. A significant challenge is the **skill gap and the need for continuous reskilling** of the workforce. Bridging the divide between academic knowledge and industry demands is crucial to ensure a steady supply of AI-ready talent.
#
# **Data privacy and security** are paramount. With vast datasets being generated, robust data protection frameworks, such as the upcoming Digital Personal Data Protection Bill, are essential to prevent misuse and ensure trust. Closely related is the critical issue of **ethical AI and bias**. Addressing algorithmic bias in decision-making, whether in credit scoring or hiring, is vital to ensure fairness, transparency, and accountability. The development of **"Explainable AI" (XAI)** is key to building public trust in AI systems.
#
# **Infrastructure and compute power** also present challenges. The need for robust cloud infrastructure and high-performance computing is growing, and ensuring equitable access across all regions of India is important. **Job displacement concerns** due to automation also need proactive strategies, focusing on human-AI collaboration and creating new roles rather than just replacing old ones. Finally, developing an agile and effective **regulatory framework** that fosters innovation while mitigating risks and balancing safety with ethics is a complex but necessary task.
#
# ### Conclusion
#
# India's AI ascent is a compelling narrative of ambition, innovation, and strategic foresight. Fueled by a unique blend of human capital, digital infrastructure, and a proactive government, the nation is not just adopting Artificial Intelligence but actively shaping its future, with a distinct focus on inclusive and impactful solutions. From revolutionizing healthcare and agriculture to transforming finance and public services, AI is proving to be a powerful catalyst for change across diverse Indian sectors.
#
# While the journey is fraught with challenges – from skill gaps and data privacy to ethical considerations and regulatory complexities – India's demonstrated ability to innovate at scale and its commitment to "AI for All" positions it uniquely on the global stage. As India continues its remarkable AI ascent, the synergy of its talent, digital infrastructure, and policy vision holds the key to unlocking a future where AI truly empowers every Indian. How do you envision AI transforming your daily life in India over the next decade? Share your thoughts below!
